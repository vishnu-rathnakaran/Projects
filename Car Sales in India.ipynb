# %% [markdown]
# ## Second Car Sales in India
#
# ### The given data set is the car sales in india .The Given Data set has list of  factors effects the price of second car sales in india the main factors effects sales are
#
# ### Main Factors
#      1)Kilometers Driven
#      2)Fuel Type used in Car
#      3)Seller Type
#      4)Transmission used in the car
#      5)Owner type

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fetching Data Values
#
# #### EDA over the data

# %%
df = pd.read_csv('car_data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# #### Dropping the Unwanted columns in the data sheet as part of cleaning process.

# %%
df.drop(['Car_Name','Owner'],axis = 1,inplace=True)
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission
# 0       Manual
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %% [markdown]
# #### Plotting pie chart for the data sets

# %%
plt.figure(figsize=(23,8))
labels = df['Seller_Type'].value_counts().index.tolist()
values = df['Seller_Type'].value_counts().tolist()
dia1 = plt.pie(values, labels=labels, autopct="%1.2f%%", shadow=True, explode=[0, 0.2])
plt.show(dia1)

labels = df['Fuel_Type'].value_counts().index.tolist()
values = df['Fuel_Type'].value_counts().tolist()
dia2 = plt.pie(values,labels = labels, autopct="%1.3f%%", shadow= True, explode=[0,.2,.2])
plt.show(dia2)

# %% [markdown]
# #### The pie charts above shows owner types in which 64.78% car enters in the second hand market is of Dealer based vehicles and rest 35.22% of car comes under the ownership of individual.
# #### The second pie chart shows the fuel used in car sales.The pie chart shows the majority of the users are using the Petrol on the    vehicle with total percentage of 79.402% ,with second of users using the diesel as the most used fuel with a percentage 19.934%.Only less amount of peoples uses CNG .664% .

# %% [markdown]
# ### Getting dummies of the given data set

# %%
df_new = pd.get_dummies(df,drop_first= True)
df_new.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000                 0
# 1  2013           4.75           9.54       43000                 1
# 2  2017           7.25           9.85        6900                 0
# 3  2011           2.85           4.15        5200                 0
# 4  2014           4.60           6.87       42450                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
df_new.corr()
# Out:
#                             Year  Selling_Price  Present_Price  Kms_Driven  \
# Year                    1.000000       0.236141      -0.047584   -0.524342
# Selling_Price           0.236141       1.000000       0.878983    0.029187
# Present_Price          -0.047584       0.878983       1.000000    0.203647
# Kms_Driven             -0.524342       0.029187       0.203647    1.000000
# Fuel_Type_Diesel        0.064315       0.552339       0.473306    0.172515
# Fuel_Type_Petrol       -0.059959      -0.540571      -0.465244   -0.172874
# Seller_Type_Individual -0.039896      -0.550724      -0.512030   -0.101419
# Transmission_Manual     0.000394      -0.367128      -0.348715   -0.162510
#
#                         Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Year                            0.064315         -0.059959
# Selling_Price                   0.552339         -0.540571
# Present_Price                   0.473306         -0.465244
# ...

# %% [markdown]
# #### Checking box plot of the datas of each columns

# %%
plt.figure(figsize=(15,20))
count = 1
for col in df_new.columns:
    plt.subplot(6,2,count)
    plt.boxplot(df_new[col])
    plt.title(col)
    count+=1
plt.show()

# %% [markdown]
# #### Pairpolot with help of seaborn libraires to get the co-realtionship between the data's

# %%
import seaborn as sns
sns.pairplot(df_new.iloc[:,:-1])

# %% [markdown]
# #### Heat map for the co-relationship

# %%
plt.figure(figsize=(20,8))
ax = sns.heatmap(df_new.corr(),annot=True,fmt = '.3f',linewidths=.5,cmap="Blues")

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           301 non-null    int64
#  1   Selling_Price  301 non-null    float64
#  2   Present_Price  301 non-null    float64
#  3   Kms_Driven     301 non-null    int64
#  4   Fuel_Type      301 non-null    object
#  5   Seller_Type    301 non-null    object
#  6   Transmission   301 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 16.6+ KB

# %% [markdown]
# #### Applying linear regression model for the data,finding the accuracy score ,r2 score and MSE of the model

# %%
x = df_new.drop('Selling_Price', axis = 1)
y = df_new['Selling_Price']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error

# %%
model = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.3, random_state = 0)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8909203033603271

# %%
model.score(x_test,y_test)
# Out:
# 0.8518199591065112

# %%
y_pred = model.predict(x_test)
plt.plot(y_test,y_pred)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 4.431480705973262
