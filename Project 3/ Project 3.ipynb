# %% [markdown]
# ## Sale Data of products
#
# #### From the Given data it measures the sale details of a prodcuts of particular company.The sale output of products depends on various dependent factors in the data sheet.From the given it needs to check the dependent variables and independent variables that effect the sale of the product.

# %% [markdown]
# ### Intializing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Calling the data sets and defing the data set into a variable
#
#
# #### Exploratory data anlysis over the data

# %%
df = pd.read_csv('Sales.csv')
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# 1         39          0.00        15.54
# 2         34         30.19        27.97
# 3         20        133.93        83.15
# 4         28          4.00        23.99

# %% [markdown]
# ### checking the null values in the data

# %%
df.isnull().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag            122921
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %% [markdown]
# #### Dropping the unwanted columns and make dummies of the data set

# %%
df = df.drop(['Order','SoldCount','ReleaseYear','SKU_number','New_Release_Flag'] , axis = 1)
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    SoldFlag  ReleaseNumber  StrengthFactor  PriceReg  ItemCount  LowUserPrice  \
# 0       0.0             15        682743.0     44.99          8         28.97
# 1       0.0              7       1016014.0     24.81         39          0.00
# 2       0.0              0        340464.0     46.00         34         30.19
# 3       1.0              4        334011.0    100.00         20        133.93
# 4       1.0              2       1287938.0    121.95         28          4.00
#
#    LowNetPrice  File_Type_Active  File_Type_Historical  MarketingType_D  \
# 0        31.84                 0                     1                1
# 1        15.54                 0                     1                1
# 2        27.97                 0                     1                1
# 3        83.15                 0                     1                1
# 4        23.99                 0                     1                1
#
#    MarketingType_S
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
df.shape
# Out:
# (198917, 11)

# %%
df.isnull().sum()
# Out:
# SoldFlag                122921
# ReleaseNumber                0
# StrengthFactor               0
# PriceReg                     0
# ItemCount                    0
# LowUserPrice                 0
# LowNetPrice                  0
# File_Type_Active             0
# File_Type_Historical         0
# MarketingType_D              0
# MarketingType_S              0
# dtype: int64

# %% [markdown]
# ####  With seaborn library making therealtionship with each columns

# %%
import seaborn as sns
sns.pairplot(df.iloc[:,:-1])

# %% [markdown]
# ### checking the Co-orelation between each columns

# %%
df.corr()
# Out:
#                       SoldFlag  ReleaseNumber  StrengthFactor  PriceReg  \
# SoldFlag              1.000000       0.075940       -0.144816  0.084213
# ReleaseNumber         0.075940       1.000000       -0.066511  0.167343
# StrengthFactor       -0.144816      -0.066511        1.000000  0.033239
# PriceReg              0.084213       0.167343        0.033239  1.000000
# ItemCount             0.236860       0.164814       -0.249535  0.067112
# LowUserPrice          0.058525       0.086223        0.022484  0.135210
# LowNetPrice          -0.013734       0.017594        0.055824  0.117767
# File_Type_Active           NaN      -0.150642       -0.054409 -0.071030
# File_Type_Historical       NaN       0.150642        0.054409  0.071030
# MarketingType_D       0.220692       0.044706        0.314011  0.160178
# MarketingType_S      -0.220692      -0.044706       -0.314011 -0.160178
#
#                       ItemCount  LowUserPrice  LowNetPrice  File_Type_Active  \
# SoldFlag               0.236860      0.058525    -0.013734               NaN
# ReleaseNumber          0.164814      0.086223     0.017594         -0.150642
# StrengthFactor        -0.249535      0.022484     0.055824         -0.054409
# PriceReg               0.067112      0.135210     0.117767         -0.071030
# ItemCount              1.000000      0.002236    -0.071282         -0.050631
# LowUserPrice           0.002236      1.000000     0.045149         -0.292880
# LowNetPrice           -0.071282      0.045149     1.000000         -0.002167
# File_Type_Active      -0.050631     -0.292880    -0.002167          1.000000
# File_Type_Historical   0.050631      0.292880     0.002167         -1.000000
# MarketingType_D        0.069350      0.040640     0.041853          0.047821
# MarketingType_S       -0.069350     -0.040640    -0.041853         -0.047821
#
#                       File_Type_Historical  MarketingType_D  MarketingType_S
# SoldFlag                               NaN         0.220692        -0.220692
# ReleaseNumber                     0.150642         0.044706        -0.044706
# StrengthFactor                    0.054409         0.314011        -0.314011
# PriceReg                          0.071030         0.160178        -0.160178
# ItemCount                         0.050631         0.069350        -0.069350
# LowUserPrice                      0.292880         0.040640        -0.040640
# LowNetPrice                       0.002167         0.041853        -0.041853
# File_Type_Active                 -1.000000         0.047821        -0.047821
# File_Type_Historical              1.000000        -0.047821         0.047821
# MarketingType_D                  -0.047821         1.000000        -1.000000
# MarketingType_S                   0.047821        -1.000000         1.000000

# %% [markdown]
# #### Heat Map to check the co relation

# %%
plt.figure(figsize=(20,8))
ax = sns.heatmap(df.corr(),annot = True, fmt =".3f",linewidths=.5, cmap="Blues")

# %%
train=df[df.SoldFlag.notnull()]
X = train.drop(["SoldFlag"],axis=1)
Y = train.SoldFlag

# %% [markdown]
# ### Training Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2)

# %%
x_train.head()
# Out:
#        ReleaseNumber  StrengthFactor  PriceReg  ItemCount  LowUserPrice  \
# 22530             10        783133.0     89.95         30         50.80
# 63902              2        391468.0     95.00         15          0.00
# 33237              4       1134536.0    106.00         44         75.00
# 19334              2       2157176.0     60.00         14          0.00
# 73705              3        131805.0     44.99         53         30.79
#
#        LowNetPrice  File_Type_Active  File_Type_Historical  MarketingType_D  \
# 22530        76.95                 0                     1                1
# 63902        32.99                 0                     1                0
# 33237        45.77                 0                     1                1
# 19334        58.51                 0                     1                1
# 73705        36.99                 0                     1                0
#
#        MarketingType_S
# 22530                0
# 63902                1
# 33237                0
# 19334                0
# 73705                1

# %% [markdown]
# #### As in the pairplot we can test the data with Logistic Regression..In the output we can say that output is continues so regression is best and check this with logistci regression

# %% [markdown]
# ### Model Building
#
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
main_model = LogisticRegression()

# %%
main_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Prediction

# %%
y_pred = main_model.predict(x_test)

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8272292644414229

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[18860,     0],
#        [ 3939,     0]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91     18860
#          1.0       0.00      0.00      0.00      3939
#
#     accuracy                           0.83     22799
#    macro avg       0.41      0.50      0.45     22799
# weighted avg       0.68      0.83      0.75     22799
# C:\Users\vishn\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,fmt=".3f",linewidths=.5)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(33.0, 0.5, 'Actual')
